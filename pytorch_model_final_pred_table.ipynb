# %%
import import_ipynb
from pytorch_model_fns import SpectrogramCNN, load_model, predict_table, eval_predict_table
import pandas as pd

# %%
model = SpectrogramCNN(dropout_rate=0.5)
trained_model = load_model(model, load_path='/Users/hela/Code/pata/best_model1.pth')
# Out:
# Spectrogram (224x224) CNN model
# Architecture:
# - 4 convolutional blocks (BatchNorm, ReLU, MaxPool)
# - global average pooling
# - 3 fully connected layers with dropout
#
#
# Best model from: epoch 17
# Validation Accuracy: 97.22%
# Validation Loss: 0.1215

# %% [markdown]
# # Get table of preds

# %%
# predict_table(trained_model, csv_file='/Users/hela/Code/pata/data_labeling.csv')

# %% [markdown]
# # Evaluate prediction table

# %%
eval_predict_table(csv_file='/Users/hela/Code/pata/data_predicted.csv', conf_low=0, conf_high=0.96, unchecked_only=True)
# Out:
# HBox(children=(Button(description='❌', style=ButtonStyle()), Button(description='✅', style=ButtonStyle())))
# HBox(children=(Button(description='Broken', style=ButtonStyle()), Button(description='->', style=ButtonStyle()…
# HBox(children=(Output(),))
# HBox(children=(Button(description='Save progress', style=ButtonStyle()),))

# %%
# CHECK FINAL TABLE
df_preds = pd.read_csv('/Users/hela/Code/pata/data_predicted.csv')
df_checked = df_preds[df_preds['label'].notna()]
print(f'Corrected predictions among checked trials: {(df_checked['label'] != df_checked['predict']).sum()}/{len(df_checked)} ({(df_checked['label'] == 'err').sum()} broken trials)')
# Out:
# Corrected predictions among checked trials: 248/2196 (36 broken trials)
